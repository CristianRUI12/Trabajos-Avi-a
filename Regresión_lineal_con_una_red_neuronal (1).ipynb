# %%
import pandas as pd

datos = pd.read_csv("Celsuis.csv")

# %% [markdown]
# ## Parte 1: Cómo funciona una red neuronal
#
# Una red neuronal aprende a partir de ejemplos.
# En este ejercicio aprenderá la relación entre Celsius y Fahrenheit..

# %%
datos.head()
# Out:
#    Celsius   Fahrenheit
# 0      -40        -40.0
# 1      -10         14.0
# 2        0         32.0
# 3        8         46.4
# 4       15         59.0

# %%
datos["Celsius"].values
# Out:
# array([-40, -10,   0,   8,  15,  22,  38])

# %% [markdown]
# ## Datos de entrenamiento

# %%
x = datos["Celsius"].values
y = datos[' Fahrenheit'].values

# %% [markdown]
# ## Parte 2: Red neuronal de regresión
#
# Se crea una red neuronal sencilla para realizar predicciones.

# %% [markdown]
# ## Compilación del modelo

# %%
import tensorflow as tf

modelo = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1),
])
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
entrenamiento = modelo.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 780ms/step - loss: 4343.8364
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 4066.8230
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 3801.5449
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 3548.1870
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 3306.9119
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 3077.8440
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2861.0767
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2656.6660
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2464.6250
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2284.9253
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2117.4924
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1962.2040
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1818.8887
# Epoch 14/1000
# ...

# %% [markdown]
# ## Gráfica del error

# %%
import matplotlib.pyplot as plt

plt.xlabel("# Epoca")
plt.ylabel("Magnitud de la perdida")
plt.plot(entrenamiento.history["loss"])

# %% [markdown]
# ## Predicción

# %%
c = 1230

prediccion = modelo.predict(np.array([c]))
print(f"prediccion: {c} celsius son {prediccion[0]} fahrenheit")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# prediccion: 1230 celsius son [2246.3418] fahrenheit

# %%
print (modelo.layers[0].get_weights())
# Out:
# [array([[1.8003069]], dtype=float32), array([31.964235], dtype=float32)]

# %% [markdown]
# ## Conclusión
#
# La red neuronal logró aprender la relación entre Celsius y Fahrenheit y pudo realizar predicciones correctamente.

# %%
#Calculo real para convertir celsius a fahrenheit es
# (C * 1.8) + 32

# %%
#Backpropagation / Propagacion hacia atras.
