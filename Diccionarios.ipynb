# %%
alumno = {
    "Nombre": "cristian ruiz",
    "Edad": 17,
    "Matricula": "231690084-0",
    "Peso": 68,
    "Carrera": "CDIA",
    "Telefono": 3112341604,
    "Domicilio": "hortencia #77"
}


print("=== DATOS DEL ALUMNO ===")
for clave, valor in alumno.items():
    print(f"{clave}: {valor}")


print(f"\nEl estudiante {alumno['Nombre']} vive actualmente en Avenida mexico.")
print(f"Tiene {alumno['Edad']} años, por lo tanto es menor de edad.")
# Out:
# === DATOS DEL ALUMNO ===
# Nombre: cristian ruiz
# Edad: 17
# Matricula: 231690084-0
# Peso: 68
# Carrera: CDIA
# Telefono: 3112341604
# Domicilio: hortencia #77
#
# El estudiante cristian ruiz vive actualmente en Avenida mexico.
# Tiene 17 años, por lo tanto es menor de edad.
